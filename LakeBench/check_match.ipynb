# %%
import pandas as pd

# %%
df = pd.read_csv('./matching_lakebench.csv')

# %%
df
# Out:
#                                 source                          compare  \
# 0      USA_CSV0000000000037101__16.csv  USA_CSV0000000000033847__23.csv
# 1       USA_CSV0000000000033847__5.csv  USA_CSV0000000000034882__27.csv
# 2       USA_CSV0000000000033847__4.csv   USA_CSV0000000000037101__2.csv
# 3       USA_CSV0000000000033847__5.csv   USA_CSV0000000000033847__9.csv
# 4      USA_CSV0000000000037101__16.csv   USA_CSV0000000000037101__5.csv
# ...                                ...                              ...
# 31936       UK_CSV0000000000007196.csv       UK_CSV0000000000002128.csv
# 31937   UK_CSV0000000000008330__70.csv   UK_CSV0000000000000197__00.csv
# 31938    UK_CSV0000000000009336__5.csv    UK_CSV0000000000000344__6.csv
# 31939    UK_CSV0000000000009446__5.csv    UK_CSV0000000000001818__3.csv
# 31940    UK_CSV0000000000070387__6.csv    UK_CSV0000000000040334__9.csv
#
#        col_iguais  col_diferentes  col_dificuldade
# 0               9              52         0.852459
# ...

# %%
df = df[(df.col_iguais > 1) & (df.col_diferentes > 1) & (df.col_dificuldade > 0.1) & (df.col_dificuldade < 0.8)]

# %%
df['country'] = df['source'].str.split('_', n=1).str[0]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1960\450479243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['source'].str.split('_', n=1).str[0]

# %%
df['total_col'] = df['col_iguais'] + df['col_diferentes']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1960\126711576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_col'] = df['col_iguais'] + df['col_diferentes']

# %%
df = df[df.total_col > 30]
df.to_csv('./candidatos_match.csv')
