# %%
import kaggle
import pandas as pd
import time

# %%
k = kaggle.api
k.authenticate()

# %%
df = pd.read_csv('./datasets_kaggle.csv')

# %%
novo_df= []

# %%
for index, row in df.iterrows():
    f = k.dataset_list_files(row['ref']).to_dict().get('datasetFiles','')
    linha = row.copy()
    
    if f:
        for file in f:
            file_name = file['name']
            linha['file_name'] = file_name
    
    novo_df.append(linha)
            
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In [24], line 2
#       1 for index, row in df.iterrows():
# ----> 2     f = k.dataset_list_files(row['ref']).to_dict().get('datasetFiles','')
#       3     linha = row.copy()
#       5     if f:
#
# File c:\Python310\lib\site-packages\kaggle\api\kaggle_api_extended.py:1497, in KaggleApi.dataset_list_files(self, dataset, page_token, page_size)
#    1495 request.page_token = page_token
#    1496 request.page_size = page_size
# -> 1497 response = kaggle.datasets.dataset_api_client.list_dataset_files(request)
#    1498 return response
#
# File c:\Python310\lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:44, in DatasetApiClient.list_dataset_files(self, request)
#      41 if request is None:
#      42   request = ApiListDatasetFilesRequest()
# ---> 44 return self._client.call("datasets.DatasetApiService", "ApiListDatasetFiles", request, ApiListDatasetFilesResponse)
#
# File c:\Python310\lib\site-packages\kagglesdk\kaggle_http_client.py:126, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#     123 settings = self._session.merge_environment_settings(http_request.url, {}, None, None, None)
#     124 http_response = self._session.send(http_request, **settings)
# --> 126 response = self._prepare_response(response_type, http_response)
#     127 return response
#
# File c:\Python310\lib\site-packages\kagglesdk\kaggle_http_client.py:191, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     189 def _prepare_response(self, response_type, http_response):
#     190   self._print_response(http_response)
# --> 191   http_response.raise_for_status()
#     192   if 'application/json' in http_response.headers['Content-Type']:
#     193     resp = http_response.json()
#
# File c:\Python310\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.kaggle.com/api/v1/datasets/list/umasarker/email-spam-detection?pagesize=20

# %%
novo_df = pd.DataFrame(novo_df)

# %%
novo_df.to_csv('./datasets_kaggle_2.csv', index=False)
