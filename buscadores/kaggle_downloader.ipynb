# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rohansirohia/mncs-financial-data20102014")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/rohansirohia/mncs-financial-data20102014?dataset_version_number=1...
# 100%|██████████| 37.9k/37.9k [00:00<00:00, 423kB/s]
# Extracting files...
# Path to dataset files: C:\Users\user\.cache\kagglehub\datasets\rohansirohia\mncs-financial-data20102014\versions\1

# %%
import pandas as pd
import os
df_list = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        file = os.path.join(path, file)
        df = pd.read_csv(file, nrows=0)  # Read only the header
        df_list.append(df)
    
print("DataFrame headers:")
for df in df_list:  
    print(df.columns.tolist())
# Out:
# DataFrame headers:
# ['Company Name', 'PL_Net Sales', 'PL_Operating Profit (Excl OI)', 'PL_Consolidated PAT', 'OCF', 'OCF/PAT', 'ROE', 'ROCE', 'D/E', 'Asset Turnover', 'FR_PBIDTM (%)', 'FR_PATM (%)', 'FR_Dividend Pay Out Ratio(%)', 'Free Float', 'Ev/EBITDA', 'M/Sales']
# ['Company Name', 'Net Sales', 'PBIDTM (%)', 'PATM (%)', 'ROE (%)', 'ROCE (%)', 'Asset Turnover(x)', 'Total Debt/Equity(x)', 'OCF', 'PAT', 'OCF/PAT', 'FR_Dividend Pay Out Ratio(%)', 'Free Float', 'Ev/EBITDA', 'M/Sales']
# ['Company Name', 'Net Sales', 'PBIDTM (%)', 'PATM (%)', 'ROE (%)', 'ROCE (%)', 'Asset Turnover(x)', 'Total Debt/Equity(x)', 'Cons OCF', 'Cons PAT', 'OCF/PAT', 'FR_Dividend Pay Out Ratio(%)', 'Free Float', 'Ev/EBITDA', 'M/Sales']
# ['Company Name', 'Net Sales', 'Cons PAT', 'Cons OCF', 'OCF/PAT', 'PBIDTM (%)', 'PATM (%)', 'FR_Dividend Pay Out Ratio(%)', 'ROE (%)', 'ROCE (%)', 'Asset Turnover(x)', 'Total Debt/Equity(x)', 'Free Float', 'Ev/EBITDA', 'M/Sales']
# ['Company Name', 'Net Sales', 'Cons PAT', 'Cons OCF', 'OCF/PAT', 'PBIDTM (%)', 'PATM (%)', 'FR_Dividend Pay Out Ratio(%)', 'ROE (%)', 'ROCE (%)', 'Asset Turnover(x)', 'Total Debt/Equity(x)', 'Free Float', 'Ev/EBITDA', 'M/Sales']

# %%
print(path)
# Out:
# C:\Users\user\.cache\kagglehub\datasets\rohansirohia\mncs-financial-data20102014\versions\1
